# %%
# %pylab inline
import math
import turtle as t
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
longinit=100

# %%
#El triángulo
t.down() 

t.forward(longinit) #A

t.left(120) #I

t.forward(longinit) #A

t.left(120)#I

t.forward(longinit) #A


t.done()

# %%
#Primer orden
t.down()

t.forward(longinit/3) #A
t.right(60)#D
t.forward(longinit/3)#A
t.left(120)#I
t.forward(longinit/3)#A
t.right(60)#D
t.forward(longinit/3)#A

t.left(120) #I

t.forward(longinit/3)#A
t.right(60)#D
t.forward(longinit/3)#A
t.left(120)#I
t.forward(longinit/3)#A
t.right(60)#D
t.forward(longinit/3)#A

t.left(120)

t.forward(longinit/3)
t.right(60)
t.forward(longinit/3)
t.left(120)
t.forward(longinit/3)
t.right(60)
t.forward(longinit/3)
t.done()

# %%
#Segundo orden
t.down()

t.forward(longinit/9)
t.right(60)
t.forward(longinit/9)
t.left(120)
t.forward(longinit/9)
t.right(60)
t.forward(longinit/9)

t.right(60)

t.forward(longinit/9)
t.right(60)
t.forward(longinit/9)
t.left(120)
t.forward(longinit/9)
t.right(60)
t.forward(longinit/9)

t.left(120)

t.forward(longinit/9)
t.right(60)
t.forward(longinit/9)
t.left(120)
t.forward(longinit/9)
t.right(60)
t.forward(longinit/9)

t.right(60)

t.forward(longinit/9)
t.right(60)
t.forward(longinit/9)
t.left(120)
t.forward(longinit/9)
t.right(60)
t.forward(longinit/9)

t.left(120)

t.forward(longinit/9)
t.right(60)
t.forward(longinit/9)
t.left(120)
t.forward(longinit/9)
t.right(60)
t.forward(longinit/9)

t.right(60)

t.forward(longinit/9)
t.right(60)
t.forward(longinit/9)
t.left(120)
t.forward(longinit/9)
t.right(60)
t.forward(longinit/9)

t.left(120)

t.forward(longinit/9)
t.right(60)
t.forward(longinit/9)
t.left(120)
t.forward(longinit/9)
t.right(60)
t.forward(longinit/9)

t.right(60)

t.forward(longinit/9)
t.right(60)
t.forward(longinit/9)
t.left(120)
t.forward(longinit/9)
t.right(60)
t.forward(longinit/9)


t.left(120)

t.forward(longinit/9)
t.right(60)
t.forward(longinit/9)
t.left(120)
t.forward(longinit/9)
t.right(60)
t.forward(longinit/9)

t.right(60)

t.forward(longinit/9)
t.right(60)
t.forward(longinit/9)
t.left(120)
t.forward(longinit/9)
t.right(60)
t.forward(longinit/9)

t.left(120)

t.forward(longinit/9)
t.right(60)
t.forward(longinit/9)
t.left(120)
t.forward(longinit/9)
t.right(60)
t.forward(longinit/9)

t.right(60)

t.forward(longinit/9)
t.right(60)
t.forward(longinit/9)
t.left(120)
t.forward(longinit/9)
t.right(60)
t.forward(longinit/9)
t.done()

# %% [markdown]
# Es evidente que si se comienza con un triángulo que recibe instrucciones correspondientes a:
# + Adelante
# + Izquierda
# + Adelante
# + Izquierda
# + Adelante
#
# Para el siguiente orden (1) es necesario cambiar las instrucciones de 'Adelante' por:
# + Adelante
# + Derecha
# + Adelante
# + Izquierda
# + Adelante
# + Derecha
# + Adelante
#
# Se procede a hacer un ciclo que para un orden dado reemplace todas las ocurrencias de 'Adelante' por lo antes mencionado y que, al encontrar un 'estímulo' ejecute los respectivos comandos t.xxx().

# %%
copo="AIAIA"
orden = 5

'''
if(orden==0):
    t.down() 

    t.forward(300) #A

    t.left(120) #I

    t.forward(300) #A

    t.left(120)#I

    t.forward(300) #A
'''
#elif(orden!=0):
for i in range(orden):
    copo=copo.replace("A", "ADAIADA")
for j in range(len(copo)):
    if (copo[j]=="A"):
        t.forward(100/3**(orden-1))
    elif(copo[j]=="D"):
        t.right(60)
    elif(copo[j]=="I"):
        t.left(120)

t.done()
