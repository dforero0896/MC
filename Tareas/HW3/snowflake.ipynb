# %%
# %pylab inline
import math
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import turtle
 
snowflake = "ADADA"
orden = 3
 
for i in range(orden):
    snowflake = snowflake.replace("A","AIADAIA")
 
turtle.down()
 
for move in snowflake:
    if move == "A":
        turtle.forward(100.0 / (3 ** (orden - 1)))
    elif move == "I":
        turtle.left(60)
    elif move == "D":
        turtle.right(120)
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-2-b9acfd37930f> in <module>()
#      13         turtle.forward(100.0 / (3 ** (orden - 1)))
#      14     elif move == "I":
# ---> 15         turtle.left(60)
#      16     elif move == "D":
#      17         turtle.right(120)
#
# C:\Users\DanielFelipe\Anaconda\lib\lib-tk\turtle.pyc in left(angle)
#
# C:\Users\DanielFelipe\Anaconda\lib\lib-tk\turtle.pyc in left(self, angle)
#    1612         67.0
#    1613         """
# -> 1614         self._rotate(angle)
#    1615
#    1616     def pos(self):
#
# C:\Users\DanielFelipe\Anaconda\lib\lib-tk\turtle.pyc in _rotate(self, angle)
#    3106             for _ in range(steps):
#    3107                 self._orient = self._orient.rotate(delta)
# -> 3108                 self._update()
#    3109         self._orient = neworient
#    3110         self._update()
#
# ...

# %%
longinit=2

# %%
inicialx=np.asarray([0, longinit*np.cos(pi/3), 2, 0])
inicialy=np.asarray([0, longinit*np.sin(pi/3), 0, 0])
despuesx=np.asarray([0, (longinit/3.)*np.cos(pi/3.), ((longinit/3.)+(longinit/9.))*np.cos(2.*pi/3.), ((2./3.)+(2./9.))*np.cos(pi/3.), 2.*np.cos(pi/3.)])
despuesy=np.asarray([0, (longinit/3.)*np.sin(pi/3.), ((longinit/3.)+(longinit/9.))*np.sin(2.*pi/3.), ((2./3.)+(2./9.))*np.sin(pi/3.), 2.*np.sin(pi/3.)])

# %%
figura, ax=plt.subplots(1, 1, figsize=(10, 10))
ax.set_xlim(-2, 2)
ax.set_ylim(-2, 2)
ax.plot(inicialx, inicialy)
ax.scatter(despuesx, despuesy)
