# %%
# %pylab inline
import math
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
L=np.linspace(-pi, 100, 1000)

# %%
plt.xkcd()
def FuncSenFactorial(x, orden):
    n=1
    total=0  
    while n<orden:
        a = (-1)**(n-1)*((x**(2*n-1))/(math.factorial(2*n-1)))
        total+=a
        n += 1
    return total

Funcsenfac, ax=subplots(1, 1, figsize=(10, 7))
ax.set_xlim(0, 20)
ax.set_ylim(-2, 2)
for i in range(2, 30):
   ax.plot(L, FuncSenFactorial(L, i)) 


#ax.plot(L, FuncSen(L, 2))
#ax.plot(L, sin(L))

# %%
def FuncSen(x, orden):
    n=2
    term=x
    total=term
    for n in range(orden):
        term*=-x**2/((2*n-1)*(2*n-2))
        total+=term
    return total

# %%
Funcsen, ax=subplots(1, 1, figsize=(10, 7))
ax.set_xlim(-pi, 10)
ax.set_ylim(-2, 2)
numsin=vectorize(FuncSen)#, excluded=['orden'])
ax.plot(L, numsin(L, 10))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-175-360836a7fa6a> in <module>()
#       3 ax.set_ylim(-2, 2)
#       4 numsin=vectorize(FuncSen)#, excluded=['orden'])
# ----> 5 ax.plot(L, numsin(L, 10))
#
# C:\Users\DanielFelipe\Anaconda\lib\site-packages\numpy\lib\function_base.pyc in __call__(self, *args, **kwargs)
#    1686             vargs.extend([kwargs[_n] for _n in names])
#    1687
# -> 1688         return self._vectorize_call(func=func, args=vargs)
#    1689
#    1690     def _get_ufunc_and_otypes(self, func, args):
#
# C:\Users\DanielFelipe\Anaconda\lib\site-packages\numpy\lib\function_base.pyc in _vectorize_call(self, func, args)
#    1755                       for _a in args]
#    1756
# -> 1757             outputs = ufunc(*inputs)
#    1758
#    1759             if ufunc.nout == 1:
#
# <ipython-input-174-c51f92387e0d> in FuncSen(x, orden)
#       4     total=term
#       5     for n in range(orden):
# ----> 6         term*=-x**2/((2*n-1)*(2*n-2))
#       7         total+=term
#       8     return total
#
# ZeroDivisionError: float division by zero
